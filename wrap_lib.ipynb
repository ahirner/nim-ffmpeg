# %%
import subprocess as sp
import re
import os
from glob import glob

# %%
c2nim = "../c2nim/c2nim"
default_lib = "av.c2nim"

inc_sys = re.compile(r"(?<=\<).+?(?=\>)")
inc_loc = re.compile(r"\"(.+?)\"")

# %%
discard_mods = ["avconfig", "common", "bprint", "avstring", "intreadwrite", "mem", "error",
               "log", "mathematics", "rational", "version"]
new_incs = ["../nim_ffmpeg_common.h"]

ffmpeg_libs = set(["libavutil", "libavcodec", "libavformat", "libswscale"])

# %%
def dynlib_header(lib):
    
    l = lib.split("lib",1)[-1]
    
    h = """\
    #ifdef C2NIM
    #  dynlib {l}dll
    #  cdecl
    #  if defined(windows)
    #    define {l}dll "{l}.dll"
    #  elif defined(macosx)
    #    define {l}dll "{lib}.dylib"
    #  else
    #    define {l}dll "{lib}.so"
    #  endif
    #endif
    """.format(l=l, lib=lib)
    
    return h

# %%
def purge_includes(fn, matchers): 

    lines = []
    includes = [[] for _ in matchers]
    
    with open(fn, "r") as f:
        
        for i, l in enumerate(f):
            if "#include" in l:
                lines.append(f"//{l.strip()} // #{i}\n")
                
                total_inc = 0
                for inc, m in zip(includes, matchers):
                    
                    what = m.findall(l)
                    
                    nr_incs = len(what)
                    assert nr_incs <= 1
                    
                    total_inc += nr_incs 
                    inc += what
                    
                assert total_inc >= 1 
                    
            else:
                lines.append(l)

        return "".join(lines), includes

# %%
def preproc(string):
    
    args = ['cpp','-E', '-P']
    cpp = sp.Popen(args, universal_newlines=True, stdin=sp.PIPE, stderr=sp.PIPE, stdout=sp.PIPE)
    out, err = cpp.communicate(string)
    ret = cpp.poll()
    
    if ret != 0:
        raise RuntimeError(f"Pre-processing failed because of {err} with exit code:", ret)
    
    return out, err

# %%
def conv2nim(fn_in, folder_out):
    
    os.makedirs(folder_out, exist_ok=True)
    fn_out = os.path.join(folder_out, fn_in.rsplit(os.sep,1)[-1].rsplit(".h", 1)[0]+'.nim')
    
    args = [c2nim, default_lib, fn_in, f'--out:{fn_out}']
    #args = [c2nim, default_lib, fn_in]
    
    print(args)
    
    c2n = sp.Popen(args, universal_newlines=True, stdin=sp.PIPE, stderr=sp.PIPE, stdout=sp.PIPE)
    out, err = c2n.communicate()
    ret = c2n.poll()
    
    if ret != 0:
        raise RuntimeError(f"c2nim conversion failed because of {err} with exit code:", ret)
    
    return out, err

# %%
def preproc_lib(lib, pp_lib, exclude_mods=[]):
    
    sys_incs = {}
    loc_incs = {}

    try:
        os.mkdir(pp_lib)
    except FileExistsError:
        pass

    
    header = dynlib_header(lib)

    for fn in glob(os.path.join(lib, '*.h')):

        mod = fn.replace(lib+os.sep, "")
        if all(m not in mod for m in exclude_mods):

            pp, (si, li) = purge_includes(fn, (inc_sys, inc_loc))
            sys_incs[mod] = si
            #loc_incs[mod] = li

            #Change to local import
            li_modified = []
            other_libs = (ffmpeg_libs-set(lib))
            for inc in li:
                
                if all(m not in inc for m in exclude_mods):
                
                    if inc.startswith(lib):
                        li_modified.append(inc.replace(lib+os.sep, ""))
                    elif any(inc.startswith(l) for l in other_libs):
                        li_modified.append('..'+os.sep+inc)
                    else:
                        li_modified.append(inc)

            loc_incs[mod] = li_modified

            print(mod, li_modified)
            
            fn_pp = os.path.join(pp_lib, mod)

            with open(fn_pp, "w") as f:
                pp_flat, _ = preproc(pp)
                
                
                
                #Add back includes such that they stay local
                incs = "\n".join(f"#include \"{i}\"" for i in (new_incs + li_modified)) + "\n"
                
                
                f.write(header + incs + pp_flat)
        
    return sys_incs, loc_incs

# %%
def c2nim_lib(lib, pp_lib):
    
    for fn in glob(os.path.join(pp_lib, '*.h')):

        try:
            out, err = conv2nim(fn, lib)
        except RuntimeError as e:
            print(fn, e)

# %%
for lib in ffmpeg_libs:
    pp_lib = "pp-"+lib
    preproc_lib(lib, pp_lib, discard_mods)
# Out:
# avcodec.h ['../libavutil/samplefmt.h', '../libavutil/attributes.h', '../libavutil/avutil.h', '../libavutil/buffer.h', '../libavutil/cpu.h', '../libavutil/channel_layout.h', '../libavutil/dict.h', '../libavutil/frame.h', '../libavutil/pixfmt.h']
# avdct.h ['../libavutil/opt.h']
# avfft.h []
# d3d11va.h []
# dirac.h ['avcodec.h']
# dv_profile.h ['../libavutil/pixfmt.h', 'avcodec.h']
# dxva2.h []
# jni.h []
# mediacodec.h ['avcodec.h']
# qsv.h ['../libavutil/buffer.h']
# vaapi.h ['../libavutil/attributes.h']
# vda.h ['avcodec.h']
# vdpau.h ['../libavutil/attributes.h', 'avcodec.h']
# videotoolbox.h ['avcodec.h']
# vorbis_parser.h []
# xvmc.h ['../libavutil/attributes.h', 'avcodec.h']
# avformat.h ['../libavcodec/avcodec.h', '../libavutil/dict.h', 'avio.h']
# avio.h ['../libavutil/dict.h']
# swscale.h ['../libavutil/avutil.h', '../libavutil/pixfmt.h']
# adler32.h ['attributes.h']
# aes.h ['attributes.h']
# aes_ctr.h ['attributes.h']
# attributes.h []
# audio_fifo.h ['avutil.h', 'fifo.h', 'samplefmt.h']
# avassert.h ['avutil.h']
# avutil.h ['macros.h', 'pixfmt.h']
# base64.h []
# blowfish.h []
# bswap.h ['attributes.h', 'config.h']
# buffer.h []
# camellia.h []
# cast5.h []
# channel_layout.h []
# cpu.h ['attributes.h']
# crc.h ['attributes.h']
# des.h []
# dict.h []
# display.h []
# downmix_info.h ['frame.h']
# eval.h ['avutil.h']
# fifo.h ['avutil.h', 'attributes.h']
# file.h ['avutil.h']
# frame.h ['avutil.h', 'buffer.h', 'dict.h', 'samplefmt.h', 'pixfmt.h']
# hash.h []
# hmac.h []
# hwcontext.h ['buffer.h', 'frame.h', 'pixfmt.h']
# hwcontext_cuda.h ['pixfmt.h']
# hwcontext_dxva2.h []
# hwcontext_qsv.h []
# hwcontext_vaapi.h []
# hwcontext_vdpau.h []
# imgutils.h ['avutil.h', 'pixdesc.h']
# intfloat.h ['attributes.h']
# lfg.h []
# lzo.h []
# macros.h []
# mastering_display_metadata.h ['frame.h']
# md5.h ['attributes.h']
# motion_vector.h []
# murmur3.h []
# opencl.h ['dict.h']
# opt.h ['avutil.h', 'dict.h', 'pixfmt.h', 'samplefmt.h']
# parseutils.h []
# pixdesc.h ['attributes.h', 'pixfmt.h']
# pixelutils.h []
# pixfmt.h []
# random_seed.h []
# rc4.h []
# replaygain.h []
# ripemd.h ['attributes.h']
# samplefmt.h ['avutil.h', 'attributes.h']
# sha.h ['attributes.h']
# sha512.h ['attributes.h']
# spherical.h []
# stereo3d.h ['frame.h']
# tea.h []
# threadmessage.h []
# time.h []
# timecode.h []
# timestamp.h []
# tree.h ['attributes.h']
# twofish.h []
# xtea.h []

# %%
for lib in ffmpeg_libs:
    for fn in glob(os.path.join(lib, '*.nim')):
        os.remove(fn)

# %%
for lib in ffmpeg_libs:
    pp_lib = "pp-"+lib
    c2nim_lib(lib, pp_lib)
# Out:
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavcodec/avcodec.h', '--out:libavcodec/avcodec.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavcodec/avdct.h', '--out:libavcodec/avdct.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavcodec/avfft.h', '--out:libavcodec/avfft.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavcodec/d3d11va.h', '--out:libavcodec/d3d11va.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavcodec/dirac.h', '--out:libavcodec/dirac.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavcodec/dv_profile.h', '--out:libavcodec/dv_profile.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavcodec/dxva2.h', '--out:libavcodec/dxva2.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavcodec/jni.h', '--out:libavcodec/jni.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavcodec/mediacodec.h', '--out:libavcodec/mediacodec.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavcodec/qsv.h', '--out:libavcodec/qsv.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavcodec/vaapi.h', '--out:libavcodec/vaapi.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavcodec/vda.h', '--out:libavcodec/vda.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavcodec/vdpau.h', '--out:libavcodec/vdpau.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavcodec/videotoolbox.h', '--out:libavcodec/videotoolbox.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavcodec/vorbis_parser.h', '--out:libavcodec/vorbis_parser.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavcodec/xvmc.h', '--out:libavcodec/xvmc.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavformat/avformat.h', '--out:libavformat/avformat.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavformat/avio.h', '--out:libavformat/avio.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libswscale/swscale.h', '--out:libswscale/swscale.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/adler32.h', '--out:libavutil/adler32.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/aes.h', '--out:libavutil/aes.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/aes_ctr.h', '--out:libavutil/aes_ctr.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/attributes.h', '--out:libavutil/attributes.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/audio_fifo.h', '--out:libavutil/audio_fifo.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/avassert.h', '--out:libavutil/avassert.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/avutil.h', '--out:libavutil/avutil.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/base64.h', '--out:libavutil/base64.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/blowfish.h', '--out:libavutil/blowfish.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/bswap.h', '--out:libavutil/bswap.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/buffer.h', '--out:libavutil/buffer.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/camellia.h', '--out:libavutil/camellia.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/cast5.h', '--out:libavutil/cast5.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/channel_layout.h', '--out:libavutil/channel_layout.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/cpu.h', '--out:libavutil/cpu.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/crc.h', '--out:libavutil/crc.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/des.h', '--out:libavutil/des.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/dict.h', '--out:libavutil/dict.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/display.h', '--out:libavutil/display.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/downmix_info.h', '--out:libavutil/downmix_info.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/eval.h', '--out:libavutil/eval.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/fifo.h', '--out:libavutil/fifo.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/file.h', '--out:libavutil/file.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/frame.h', '--out:libavutil/frame.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/hash.h', '--out:libavutil/hash.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/hmac.h', '--out:libavutil/hmac.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/hwcontext.h', '--out:libavutil/hwcontext.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/hwcontext_cuda.h', '--out:libavutil/hwcontext_cuda.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/hwcontext_dxva2.h', '--out:libavutil/hwcontext_dxva2.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/hwcontext_qsv.h', '--out:libavutil/hwcontext_qsv.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/hwcontext_vaapi.h', '--out:libavutil/hwcontext_vaapi.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/hwcontext_vdpau.h', '--out:libavutil/hwcontext_vdpau.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/imgutils.h', '--out:libavutil/imgutils.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/intfloat.h', '--out:libavutil/intfloat.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/lfg.h', '--out:libavutil/lfg.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/lzo.h', '--out:libavutil/lzo.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/macros.h', '--out:libavutil/macros.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/mastering_display_metadata.h', '--out:libavutil/mastering_display_metadata.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/md5.h', '--out:libavutil/md5.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/motion_vector.h', '--out:libavutil/motion_vector.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/murmur3.h', '--out:libavutil/murmur3.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/opencl.h', '--out:libavutil/opencl.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/opt.h', '--out:libavutil/opt.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/parseutils.h', '--out:libavutil/parseutils.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/pixdesc.h', '--out:libavutil/pixdesc.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/pixelutils.h', '--out:libavutil/pixelutils.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/pixfmt.h', '--out:libavutil/pixfmt.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/random_seed.h', '--out:libavutil/random_seed.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/rc4.h', '--out:libavutil/rc4.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/replaygain.h', '--out:libavutil/replaygain.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/ripemd.h', '--out:libavutil/ripemd.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/samplefmt.h', '--out:libavutil/samplefmt.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/sha.h', '--out:libavutil/sha.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/sha512.h', '--out:libavutil/sha512.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/spherical.h', '--out:libavutil/spherical.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/stereo3d.h', '--out:libavutil/stereo3d.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/tea.h', '--out:libavutil/tea.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/threadmessage.h', '--out:libavutil/threadmessage.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/time.h', '--out:libavutil/time.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/timecode.h', '--out:libavutil/timecode.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/timestamp.h', '--out:libavutil/timestamp.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/tree.h', '--out:libavutil/tree.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/twofish.h', '--out:libavutil/twofish.nim']
# ['../c2nim/c2nim', 'av.c2nim', 'pp-libavutil/xtea.h', '--out:libavutil/xtea.nim']
